# %% [markdown]
# 1. Keluarkan dan tampilkan menggunakan print semua anggota list pada sel dibawah

# %%
#kerjakan soal no.1 pada sel berikut ini
#contoh list = [1,2,3]
#contoh hasil
#1
#2
#3

data_list = ['bandung', 'jakarta', 'semarang', 'palembang']

for index,data_list in enumerate(data_list) :
    print(data_list)
# Out:
# bandung
# jakarta
# semarang
# palembang

# %% [markdown]
# 2. Keluarkan dan tampilkan menggunakan metode print anggota list dengan tipe numerik (int & float) dari list pada sel di bawah

# %%
#kerjakan soal no.2 pada sel berikut ini
#contoh list = ['a', 1]
#contoh hasil :
#1

data_list_2 = [100, 'makassar', 15.5, True, "20"] 

for intorfloat in data_list_2:
    if (type(intorfloat) == int or type(intorfloat) == float):
        print(intorfloat)
# Out:
# 100
# 15.5

# %% [markdown]
# 3. Buat sebuah kode if else yang dapat menyatakan apakah suatu bilangan ganjil atau genap.

# %%
#kerjakan soal no.3 disini

number = 9

#hint
'''
if ... :
    print(...)
else ...:
    print(...)
'''
#hasil yang diharapkan
#ganjil

if number % 2 == 0: # % is modulo
    print("genap")
else:
    print("ganjil")
# Out:
# ganjil

# %% [markdown]
# 4. Kalikan semua anggota list_1 terhadap anggota ganjil pada list_2. tampilkan hasilnya

# %%
#kerjakan soal no.4 pada sel berikut ini
list_1 = [1,2,3,4,5]
list_2 = [2,3,6,8,9]


#hasil yang diharapkan
'''
3
9
6
18
9
27
12
36
15
45
'''

for number_1 in list_1:
    for number_2 in list_2:
        if number_2 %2 != 0:
        #filter if  in list_2 is odd 
            times = number_1*number_2
            print(times)
# Out:
# 3
# 9
# 6
# 18
# 9
# 27
# 12
# 36
# 15
# 45

# %% [markdown]
# 5. lakukan pengecekan apakah terdapat angka pada tiap2 anggota list. lalu tampilkan sesuai format yang diminta

# %%
#kerjakan soal no.5 pada sel berikut ini
#contoh list = ['ada', 'ganesa10']
#contoh hasil:
#ada tidak memiliki angka
#ganesa10 memiliki angka

data_list_3 = ['asda8asd', 'bandunglautanapi', 'washingt0nDC']

''' #First answer #JIKA semuanya tidak alphabet (spasi bukan alphabet)
for char in data_list_3:
    if char.isalpha() == False:
        print('{} memiliki angka'.format(char))
    else:
        print('{} tidak memiliki angka'.format(char))
    #isalpha()
    #True if all characters in the string are alphabets (can be both lowercase and uppercase).
    #False if at least one character is not alphabet.
'''

for i in data_list_3:
    if any(char.isdigit() for char in i): #find in every char have any digit (0-9)
        print('{} memiliki angka'.format(i))
    else:
        print('{} tidak memiliki angka'.format(i))
# Out:
# asda8asd memiliki angka
# bandunglautanapi tidak memiliki angka
# washingt0nDC memiliki angka

# %% [markdown]
# 6. Cari siswa mana saja yang memiliki nilai lebih dari sama dengan 80. Masukkan kedalam sebuah list. print hasilnya

# %%
data_siswa = [
    {
        "nama":"Budi",
        "nilai": 90
    },
    {
        "nama":"Nina",
        "nilai": 78
    },
    {
        "nama":"Rudi",
        "nilai": 91
    },
    {
        "nama":"Olivia",
        "nilai": 76
    },
    {
        "nama":"Leo",
        "nilai": 80
    },
    {
        "nama":"Liam",
        "nilai": 67
    },
    {
        "nama":"Sheila",
        "nilai": 76
    }
]

#hasil yang diharapkan
#[Budi, Rudi, Leo]

'''First Answer
siswa_lulus = ""

for i in data_siswa:
    if i['nilai'] >= 80:
        siswa_lulus = siswa_lulus + i['nama'] + ", "

siswa_lulus = siswa_lulus[:-2]
print("[", "]", sep=siswa_lulus)
      
'''

siswa_lulus = []

for i in data_siswa:
    if i['nilai'] >= 80:
         siswa_lulus.append(i['nama'])
        
print(siswa_lulus)
# Out:
# ['Budi', 'Rudi', 'Leo']
